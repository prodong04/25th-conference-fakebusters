# %%
import torch
from torch.utils.data import DataLoader, random_split
from cnn.classifier import Model
import yaml
import json
import numpy as np
from torch.utils.data import Dataset


# 설정
BATCH_SIZE = 32
LEARNING_RATE = 0.0001
NUM_EPOCHS = 100
VALIDATION_SPLIT = 0.2
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 데이터 준비
with open('/root/25th-conference-fakebusters/model/fakecatcher/config.yaml', 'r') as file:
    config = yaml.safe_load(file)
    fps_standard = config.get('fps_standard', 30)  # 기본값 30
    time_interval = config.get('seg_time_interval', 1)  # 기본값 1
    w = fps_standard * time_interval

with open('/root/25th-conference-fakebusters/model/fakecatcher/ppg_map_results_updated.json', 'r') as file:
    data = json.load(file)

# Extract PPG Maps and Labels
ppg_maps = []
labels = []
for item in data:
    ppg_maps.append(np.array(item['ppg_map']))  # (64, w) 형태의 배열
    labels.append(item['label'])               # 0 or 1

# Convert to numpy arrays
ppg_maps = np.array(ppg_maps)
labels = np.array(labels)     

class CustomDataset(Dataset):
    def __init__(self, data, labels):
        """
        Args:
            data (np.array): Shape (2831, 64, 90)
            labels (np.array): Shape (2831,)
        """
        self.data = torch.tensor(data, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        """
        Args:
            idx (int): Index
        Returns:
            tuple: (data_sample, label)
        """
        return self.data[idx], self.labels[idx]

dataset = CustomDataset(ppg_maps, labels)
print(f"Dataset size: {len(dataset)}")
print(f"Sample PPG map shape: {dataset[0][0].shape}")
print(f"Sample label: {dataset[0][1]}")
train_size = int((1 - VALIDATION_SPLIT) * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

# 모델 준비
model_name = 'baseCNN'  # "ResNet34", "EfficientNetB3"로 변경 가능
model = Model.get_model(model_name, w)
criterion = torch.nn.BCELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

# 학습
Model.train(model, train_loader, val_loader, criterion, optimizer, device, epochs=NUM_EPOCHS)

# # 테스트
# test_loss, test_accuracy = Model.test(model, val_loader, criterion, device)
# print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Dataset size: 2831
# Sample PPG map shape: torch.Size([64, 90])
# Sample label: 1
# Epoch 1/100, Loss: 0.8494
# Validation Loss: 0.6777, Accuracy: 0.5626
# Epoch 2/100, Loss: 0.6932
# Validation Loss: 0.6775, Accuracy: 0.5855
# Epoch 3/100, Loss: 0.6830
# Validation Loss: 0.6846, Accuracy: 0.5467
# Epoch 4/100, Loss: 0.6825
# Validation Loss: 0.6772, Accuracy: 0.5414
# Epoch 5/100, Loss: 0.6742
# Validation Loss: 0.6923, Accuracy: 0.5344
# Epoch 6/100, Loss: 0.6782
# Validation Loss: 0.6690, Accuracy: 0.5873
# Epoch 7/100, Loss: 0.6693
# Validation Loss: 0.6670, Accuracy: 0.5855
# Epoch 8/100, Loss: 0.6680
# Validation Loss: 0.6686, Accuracy: 0.5873
# Epoch 9/100, Loss: 0.6669
# Validation Loss: 0.6690, Accuracy: 0.5802
# Epoch 10/100, Loss: 0.6585
# Validation Loss: 0.6666, Accuracy: 0.5996
# Epoch 11/100, Loss: 0.6509
# Validation Loss: 0.6671, Accuracy: 0.5944
# Validation Loss: 0.8961, Accuracy: 0.6914
# Epoch 78/100, Loss: 0.0828
# Validation Loss: 0.9673, Accuracy: 0.6825
# Epoch 79/100, Loss: 0.0619
# Validation Loss: 0.9569, Accuracy: 0.6755
# Epoch 80/100, Loss: 0.0863
# Validation Loss: 0.9581, Accuracy: 0.6825
# Epoch 81/100, Loss: 0.0644
# Validation Loss: 1.0687, Accuracy: 0.6737
# Epoch 82/100, Loss: 0.0937
# Validation Loss: 1.0148, Accuracy: 0.6790
# Epoch 83/100, Loss: 0.0859
# Validation Loss: 0.9662, Accuracy: 0.6667
# Epoch 84/100, Loss: 0.0760
# Validation Loss: 0.9942, Accuracy: 0.6825
# Epoch 85/100, Loss: 0.0804
# Validation Loss: 0.9933, Accuracy: 0.6614
# Epoch 86/100, Loss: 0.0755
# Validation Loss: 0.9672, Accuracy: 0.6737
# Epoch 87/100, Loss: 0.0730
# Validation Loss: 1.0056, Accuracy: 0.6755
# Epoch 88/100, Loss: 0.0619
# Validation Loss: 0.9634, Accuracy: 0.6790
# Epoch 89/100, Loss: 0.0728
# Validation Loss: 0.9718, Accuracy: 0.6490
# Epoch 90/100, Loss: 0.0669
# Validation Loss: 1.0214, Accuracy: 0.6684
# Epoch 91/100, Loss: 0.0606
# Validation Loss: 0.9799, Accuracy: 0.6772
# Epoch 92/100, Loss: 0.0631
# Validation Loss: 1.0048, Accuracy: 0.6720
# Epoch 93/100, Loss: 0.0635
# Validation Loss: 1.0255, Accuracy: 0.6737
# Epoch 94/100, Loss: 0.0613
# Validation Loss: 0.9953, Accuracy: 0.6720
# Epoch 95/100, Loss: 0.0537
# Validation Loss: 1.0412, Accuracy: 0.6843
# Epoch 96/100, Loss: 0.0616
# Validation Loss: 1.0273, Accuracy: 0.6825
# Epoch 97/100, Loss: 0.0600
# Validation Loss: 1.0669, Accuracy: 0.6737
# Epoch 98/100, Loss: 0.0604
# Validation Loss: 1.0037, Accuracy: 0.6755
# Epoch 99/100, Loss: 0.0617
# Validation Loss: 1.0925, Accuracy: 0.6720
# Epoch 100/100, Loss: 0.0646
# Validation Loss: 1.0779, Accuracy: 0.6896

# %%
import matplotlib.pyplot as plt

# Assuming Model.train() returns the training and validation loss history
train_losses, val_losses = Model.train(model, train_loader, val_loader, criterion, optimizer, device, epochs=NUM_EPOCHS)

# Plotting the loss changes
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Changes Over Epochs')
plt.legend()
plt.show()
# Out:
# Epoch 1/100, Loss: 0.0267
# Validation Loss: 1.6056, Accuracy: 0.6631
# Epoch 2/100, Loss: 0.0395
# Validation Loss: 1.3771, Accuracy: 0.6614
# Epoch 3/100, Loss: 0.0266
# Validation Loss: 1.8077, Accuracy: 0.6543
# Epoch 4/100, Loss: 0.0284
# Validation Loss: 1.8008, Accuracy: 0.6561
# Epoch 5/100, Loss: 0.0248
# Validation Loss: 1.6707, Accuracy: 0.6649
# Epoch 6/100, Loss: 0.0267
# Validation Loss: 1.6138, Accuracy: 0.6490
# Epoch 72/100, Loss: 0.0178
# Validation Loss: 1.9200, Accuracy: 0.6437
# Epoch 73/100, Loss: 0.0258
# Validation Loss: 2.3254, Accuracy: 0.6702
# Epoch 74/100, Loss: 0.0216
# Validation Loss: 2.0847, Accuracy: 0.6667
# Epoch 75/100, Loss: 0.0342
# Validation Loss: 2.2448, Accuracy: 0.6772
# Epoch 76/100, Loss: 0.0254
# Validation Loss: 2.0323, Accuracy: 0.6649
# Epoch 77/100, Loss: 0.0179
# Validation Loss: 2.0462, Accuracy: 0.6614
# Epoch 78/100, Loss: 0.0169
# Validation Loss: 2.0559, Accuracy: 0.6614
# Epoch 79/100, Loss: 0.0253
# Validation Loss: 1.9257, Accuracy: 0.6561
# Epoch 80/100, Loss: 0.0272
# Validation Loss: 1.7508, Accuracy: 0.6455
# Epoch 81/100, Loss: 0.0266
# Validation Loss: 1.7210, Accuracy: 0.6526
# Epoch 82/100, Loss: 0.0321
# Validation Loss: 2.3176, Accuracy: 0.6578
# Epoch 83/100, Loss: 0.0215
# Validation Loss: 2.2855, Accuracy: 0.6614
# Epoch 84/100, Loss: 0.0207
# Validation Loss: 2.7676, Accuracy: 0.6455
# Epoch 85/100, Loss: 0.0243
# Validation Loss: 2.5691, Accuracy: 0.6561
# Epoch 86/100, Loss: 0.0213
# Validation Loss: 2.7596, Accuracy: 0.6631
# Epoch 87/100, Loss: 0.0122
# Validation Loss: 2.6581, Accuracy: 0.6631
# Epoch 88/100, Loss: 0.0209
# Validation Loss: 2.9013, Accuracy: 0.6808
# Epoch 89/100, Loss: 0.0143
# Validation Loss: 3.0698, Accuracy: 0.6561
# Epoch 90/100, Loss: 0.0172
# Validation Loss: 2.9798, Accuracy: 0.6772
# Epoch 91/100, Loss: 0.0162
# Validation Loss: 3.0042, Accuracy: 0.6737
# Epoch 92/100, Loss: 0.0303
# Validation Loss: 1.7993, Accuracy: 0.6966
# Epoch 93/100, Loss: 0.0320
# Validation Loss: 3.4575, Accuracy: 0.6702
# Epoch 94/100, Loss: 0.0328
# Validation Loss: 2.8773, Accuracy: 0.6720
# Epoch 95/100, Loss: 0.0197
# Validation Loss: 2.8954, Accuracy: 0.6631
# Epoch 96/100, Loss: 0.0287
# Validation Loss: 2.2721, Accuracy: 0.6578
# Epoch 97/100, Loss: 0.0308
# Validation Loss: 2.3114, Accuracy: 0.6755
# Epoch 98/100, Loss: 0.0166
# Validation Loss: 2.1608, Accuracy: 0.6843
# Epoch 99/100, Loss: 0.0220
# Validation Loss: 2.3572, Accuracy: 0.6614
# Epoch 100/100, Loss: 0.0258
# Validation Loss: 2.6347, Accuracy: 0.6631
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Assuming Model.train() returns the training and validation loss history
# ----> 4 train_losses, val_losses = Model.train(model, train_loader, val_loader, criterion, optimizer, device, epochs=NUM_EPOCHS)
#       6 # Plotting the loss changes
#       7 plt.figure(figsize=(10, 5))
#
# TypeError: cannot unpack non-iterable NoneType object
